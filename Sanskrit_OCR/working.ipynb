# %%
import cv2
import pytesseract

# %%
""" 
1. Inverted Images
2. Rescaling
3. Binarization
4. Noise Removal
5. Dilation and Erosion
6. Rotation /Deskweing
7. Removing Borders
8. Missing Borders
9. Transparency / Alpha channel
"""
# Out:
# ' \n1. Inverted Images\n2. Rescaling\n3. Binarization\n4. Noise Removal\n5. Dilation and Erosion\n6. Rotation /Deskweing\n7. Removing Borders\n8. Missing Borders\n9. Transparency / Alpha channel\n'

# %%
# Opening an Image

image_file = "data/page.png"
img = cv2.imread(image_file)
img.size
# Out:
# 356832

# %%
import matplotlib.pyplot as plt

def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)
    
    # Check if the image is grayscale or color
    if len(im_data.shape) == 2:
        height, width = im_data.shape
        depth = 1
    else:
        height, width, depth = im_data.shape

    figsize = width / float(dpi), height / float(dpi)
    
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])
    ax.axis('off')
    
    # Display using appropriate colormap
    ax.imshow(im_data, cmap='gray' if depth == 1 else None)
    
    print("Figure size (inches):", figsize)
    plt.show()

# %%
display(image_file)
# Out:
# Figure size (inches): (6.6375, 2.8)

# %% [markdown]
# ## Inverted Images

# %%
inverted_img = cv2.bitwise_not(img)
cv2.imwrite("data//inverted.jpg",inverted_img)
# Out:
# True

# %%
display("data/inverted.jpg")
# Out:
# Figure size (inches): (6.6375, 2.8)

# %% [markdown]
# ## Rescaling

# %%
# skipping for later

# %% [markdown]
# ## Binarization

# %%
def grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image = grayscale(img)
cv2.imwrite("data/gray.jpg",gray_image)
# Out:
# True

# %%
gray_image = grayscale(img)
cv2.imwrite("data/gray.jpg",gray_image)
display('data/gray.jpg')
# Out:
# Figure size (inches): (6.6375, 2.8)

# %%
thresh, im_bw = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2.imwrite("data/bw_image.jpg",im_bw)
# Out:
# True

# %%
display('data/bw_image.jpg')
# Out:
# Figure size (inches): (6.6375, 2.8)

# %% [markdown]
# ## Noise Removal

# %%
def noise_removal(image):
    import numpy as np
    kernel = np.ones((1,1), np.uint8)
    image = cv2.dilate(image, kernel, iterations=1)
    kernel = np.ones((1,1), np.uint8)
    image = cv2.erode(image, kernel, iterations=1)
    image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    image = cv2.medianBlur(image, 3)
    return image

# %%
no_noise = noise_removal(im_bw)
cv2.imwrite("data/no_noise.jpg",no_noise)
# Out:
# True

# %%
display("data/no_noise.jpg")
# Out:
# Figure size (inches): (6.6375, 2.8)

# %% [markdown]
# ## Dilation and erosion

# %%
import pytesseract
from PIL import Image

# %%
img_file = "data/inverted.jpg"
img = Image.open(img_file)
ocr_result = pytesseract.image_to_string(img)
print(ocr_result)
# Out:
# BEANAATIRT TATATATTe: |
# aaa gare: eins BratargTaa: Ul 4 Il
# pra dagReT a RAT MATT: |
# soma sane aexgars Ales AY ii
# atagrengd sarraqeaaee: |
# aqeaaaeaen freqary DI7a 1% Hl
# agaraer gear farat mega: |
# aieetaere eae: cafseniagaay 9 0

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load your image
img = Image.open("D:\Projects\Python-Projects\Sanskrit_OCR\data\hin.png")

# Run OCR with Sanskrit
text = pytesseract.image_to_string(img, lang='san+hin')  # Use 'hin' if 'san' doesn't work
with open('data1.txt', 'w', encoding='utf-8') as f:
    f.write(text)
print(text)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\manis\AppData\Local\Temp\ipykernel_19192\2570943240.py:4: SyntaxWarning: invalid escape sequence '\P'
#   img = Image.open("D:\Projects\Python-Projects\Sanskrit_OCR\data\hin.png")
# सकत
#
# प्रस्तुत संकलन में 1954 से 1960 तक की रचनाएं संग्रहीत ह । मालव-
# निवास और नेपाल-प्रवास की संचित स्मृति-राशि। विन्ध्य-हिमालय नामकरण
# इसी भाव-भूमि का परिचायक है। मालव मे मेरा मन-मयूर विन्ध्या की घनाली
# हरियाली पर भाव-विभोर, 'प्रियतम इव प्राथेना चाटुकारः, शिप्रा की तरंगों-
# सा स्मर-स्फुरित, पाताल-पानी की शनी फुहारों के साथ थिरक-धिरक उठने
# के लिए ब्यग्र हो उठता था। नेपाल में हिमालय का श्रभ्रभेदी उदात्त संभार
# देखा तो श्रवाक्‌ रह गया। जीवन में ऐसी विराद्‌ शुभ्रता, स्वर्ग के प्रति
# धरती का ऐसा उल्लास मैने कभी नहीं देखा था । पाँच वपं उसके श्रभिराम
# क्रोड मे क्रीड़ा करके फिर मालवा लौट श्राया भौर धीरे-धीरे पाँच वर्ष वीतम
# ...

# %%
import cv2

img = cv2.imread("hin.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)[1]

# Save and read again via PIL
cv2.imwrite('hindi.jpg', thresh)
text = pytesseract.image_to_string(Image.open('hindi.jpg'), lang='hi')
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       7 # Save and read again via PIL
#       8 cv2.imwrite('hindi.jpg', thresh)
# ----> 9 text = pytesseract.image_to_string(Image.open('hindi.jpg'), lang='hi')
#      10 print(text)
#
# NameError: name 'Image' is not defined
